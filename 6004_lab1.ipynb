# %%
import tensorflow as tf  # import libraries
import numpy as np
import matplotlib.pyplot as plt

#check tensorflow version
print(tf.__version__)
# Out:
# 2.9.2

# %%
from keras.datasets import fashion_mnist #import data
(X_train_full, y_train_full),(X_test, y_test) = fashion_mnist.load_data() #load data
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
class_names = ["T-shirt/top", "trouser", "pullover", "dress", "coat", "sandal", "shirt", "sneakers", "bag", "ankle boot"] #define class names

# %%
print(X_train_full.shape) #explore data, check shape 
print(y_train_full.shape)

print(X_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
X_train_full.dtype #explore data, check data type
y_train_full.dtype
# Out:
# dtype('uint8')

# %%
X_valid, X_train = X_train_full[:5000] / 255.0, X_train_full[5000:]/255.0 #preprocession, normalisation, recale the pixel values from 0-255 to the range of 0-1 
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.0

# %%
plt.figure(figsize=(10,10))  #Display first 25 images and its names from the training set

for i in range(25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(X_train_full[i], cmap = plt.cm.binary)
  plt.xlabel(class_names[y_train_full[i]])
plt.show()

# %%
model = tf.keras.models.Sequential()  #Use Keras sequential API to build your model
model.add(tf.keras.layers.Flatten(input_shape= [28,28]))
model.add(tf.keras.layers.Dense(300, activation = "relu"))
model.add(tf.keras.layers.Dense(100, activation = "relu"))
model.add(tf.keras.layers.Dense(10, activation = "softmax"))

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape= [28,28]), 
    tf.keras.layers.Dense(300, activation = "relu"), 
    tf.keras.layers.Dense(100, activation = "relu"),
    tf.keras.layers.Dense(10, activation = "softmax")] )
#create our sequential model

# %%
model.summary() #Model Summary
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 300)               235500
#
#  dense_7 (Dense)             (None, 100)               30100
#
#  dense_8 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = "sparse_categorical_crossentropy",
               optimizer= "sgd", 
               metrics=["accuracy"]) #Tweak learned parameters (learning rate, optimizers, loss functions etc)

# %%
history = model.fit(X_train, y_train, epochs = 30, validation_data= (X_valid, y_valid)) # Train the model with epochs = 30
# Out:
# Epoch 1/30
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.7103 - accuracy: 0.7655 - val_loss: 0.5131 - val_accuracy: 0.8256
# Epoch 2/30
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.4882 - accuracy: 0.8298 - val_loss: 0.4608 - val_accuracy: 0.8402
# Epoch 3/30
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.4429 - accuracy: 0.8452 - val_loss: 0.4324 - val_accuracy: 0.8510
# Epoch 4/30
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.4173 - accuracy: 0.8539 - val_loss: 0.3946 - val_accuracy: 0.8642
# Epoch 5/30
# 1719/1719 [==============================] - 15s 9ms/step - loss: 0.3967 - accuracy: 0.8588 - val_loss: 0.3827 - val_accuracy: 0.8694
# Epoch 6/30
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.3798 - accuracy: 0.8663 - val_loss: 0.3866 - val_accuracy: 0.8650
# Epoch 7/30
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.3678 - accuracy: 0.8708 - val_loss: 0.3544 - val_accuracy: 0.8788
# Epoch 8/30
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3541 - accuracy: 0.8741 - val_loss: 0.3569 - val_accuracy: 0.8780
# Epoch 9/30
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.3450 - accuracy: 0.8777 - val_loss: 0.3473 - val_accuracy: 0.8774
# Epoch 10/30
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.3353 - accuracy: 0.8808 - val_loss: 0.3417 - val_accuracy: 0.8840
# Epoch 11/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3266 - accuracy: 0.8828 - val_loss: 0.3317 - val_accuracy: 0.8846
# Epoch 12/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3178 - accuracy: 0.8863 - val_loss: 0.3300 - val_accuracy: 0.8842
# Epoch 13/30
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.3107 - accuracy: 0.8882 - val_loss: 0.3298 - val_accuracy: 0.8820
# Epoch 14/30
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3050 - accuracy: 0.8894 - val_loss: 0.3477 - val_accuracy: 0.8810
# Epoch 15/30
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2984 - accuracy: 0.8922 - val_loss: 0.3356 - val_accuracy: 0.8840
# Epoch 16/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2910 - accuracy: 0.8945 - val_loss: 0.3201 - val_accuracy: 0.8888
# Epoch 17/30
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2868 - accuracy: 0.8967 - val_loss: 0.3093 - val_accuracy: 0.8888
# Epoch 18/30
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2803 - accuracy: 0.8990 - val_loss: 0.3219 - val_accuracy: 0.8852
# Epoch 19/30
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.2750 - accuracy: 0.8999 - val_loss: 0.3124 - val_accuracy: 0.8878
# Epoch 20/30
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.2711 - accuracy: 0.9026 - val_loss: 0.3011 - val_accuracy: 0.8920
# Epoch 21/30
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2654 - accuracy: 0.9049 - val_loss: 0.3007 - val_accuracy: 0.8894
# Epoch 22/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2601 - accuracy: 0.9055 - val_loss: 0.3101 - val_accuracy: 0.8870
# Epoch 23/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2556 - accuracy: 0.9080 - val_loss: 0.2989 - val_accuracy: 0.8948
# Epoch 24/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2513 - accuracy: 0.9094 - val_loss: 0.2980 - val_accuracy: 0.8946
# Epoch 25/30
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2473 - accuracy: 0.9115 - val_loss: 0.2945 - val_accuracy: 0.8924
# Epoch 26/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2436 - accuracy: 0.9118 - val_loss: 0.3019 - val_accuracy: 0.8882
# Epoch 27/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2387 - accuracy: 0.9143 - val_loss: 0.2986 - val_accuracy: 0.8940
# Epoch 28/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2357 - accuracy: 0.9148 - val_loss: 0.2939 - val_accuracy: 0.8928
# Epoch 29/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2313 - accuracy: 0.9169 - val_loss: 0.2926 - val_accuracy: 0.8934
# Epoch 30/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2276 - accuracy: 0.9174 - val_loss: 0.2904 - val_accuracy: 0.8964

# %%
import pandas as pd #Plot learning curve
pd.DataFrame(history.history).plot(figsize= (8,5))
plt.grid(True)
plt.gca().set_ylim(0,1) #set the vertical range to [0-1]
plt.show()

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose = 2) #Evaluate the test accuracy
print("\nTest accuracy: ", test_acc)
# Out:
# 313/313 - 1s - loss: 0.3280 - accuracy: 0.8841 - 649ms/epoch - 2ms/step
#
# Test accuracy:  0.8841000199317932

# %%
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()]) #Make prediction on the test dataset
predictions = probability_model.predict(X_test)
predictions[0]

np.argmax(predictions[0])
# Out:
# 313/313 [==============================] - 1s 4ms/step
# 9

# %%
#Task 9: data privacy and professional ethics

#Do not use content-related personal data without the consent person
#protect data by passwords and encription
#Inappropriate use of data
